# %%
import torch

# %%
import stable_worldmodel as swm

# %%
import inspect
import stable_worldmodel as swm

print(getattr(swm, "__version__", "unknown"))
print(inspect.signature(swm.World))
# Out:
# unknown
# (env_name: str, num_envs: int, image_shape: tuple[int, int], goal_transform: collections.abc.Callable[[typing.Any], typing.Any] | None = None, image_transform: collections.abc.Callable[[typing.Any], typing.Any] | None = None, seed: int = 2349867, history_size: int = 1, frame_skip: int = 1, max_episode_steps: int = 100, verbose: int = 1, extra_wrappers: list[collections.abc.Callable] | None = None, goal_conditioned: bool = True, **kwargs: Any) -> None

# %%
import stable_worldmodel as swm

world = swm.World(
    env_name="swm/PushT-v1",
    num_envs=1,
    image_shape=(64, 64),
)

print(world)
# Out:
# 2026-04-06 23:29:33.082 | INFO     | stable_worldmodel.world:__init__:123 - 🌍🌍🌍 World swm/PushT-v1 initialized 🌍🌍🌍
# 2026-04-06 23:29:33.083 | INFO     | stable_worldmodel.world:__init__:125 - 🕹️ 🕹️ 🕹️ Action space 🕹️ 🕹️ 🕹️
# 2026-04-06 23:29:33.083 | INFO     | stable_worldmodel.world:__init__:126 - Box(-1.0, 1.0, (1, 2), float32)
# 2026-04-06 23:29:33.084 | INFO     | stable_worldmodel.world:__init__:128 - 👁️ 👁️ 👁️ Observation space 👁️ 👁️ 👁️
# 2026-04-06 23:29:33.084 | INFO     | stable_worldmodel.world:__init__:129 - Dict('proprio': Box(0.0, 512.0, (1, 4), float64), 'state': Box(0.0, [[512.         512.         512.         512.           6.28318531
#   512.         512.        ]], (1, 7), float64))
# 2026-04-06 23:29:33.084 | INFO     | stable_worldmodel.world:__init__:132 - ⚗️ ⚗️ ⚗️ Variation space ⚗️ ⚗️ ⚗️
# agent:
#     angle: Box(-6.283185307179586, 6.283185307179586, (), float64)
#     color: Box(0, 255, (3,), uint8)
#     scale: Box(20.0, 60.0, (), float32)
#     shape: Discrete(8)
#     start_position: Box(50.0, 450.0, (2,), float64)
#     velocity: Box(0.0, 512.0, (2,), float64)
# background:
#     color: Box(0, 255, (3,), uint8)
# block:
#     angle: Box(-6.283185307179586, 6.283185307179586, (), float64)
#     color: Box(0, 255, (3,), uint8)
#     scale: Box(20.0, 60.0, (), float32)
#     shape: Discrete(7, start=1)
#     start_position: Box(100.0, 400.0, (2,), float64)
# goal:
#     angle: Box(-6.283185307179586, 6.283185307179586, (), float64)
#     color: Box(0, 255, (3,), uint8)
#     position: Box(50.0, 450.0, (2,), float64)
#     scale: Box(20.0, 60.0, (), float32)
# rendering:
#     render_goal: Discrete(2)
# <stable_worldmodel.world.World object at 0x16e088a60>

# %%
agent:
    angle: Box(-6.283185307179586, 6.283185307179586, (), float64)。# （） 表示是一个数
    color: Box(0, 255, (3,), uint8)。# 0-255 一个三维响亮
    scale: Box(20.0, 60.0, (), float32)
    shape: Discrete(8)
    start_position: Box(50.0, 450.0, (2,), float64)
    velocity: Box(0.0, 512.0, (2,), float64)  #速度，是二维向量
background:
    color: Box(0, 255, (3,), uint8)
block:
    angle: Box(-6.283185307179586, 6.283185307179586, (), float64)
    color: Box(0, 255, (3,), uint8)
    scale: Box(20.0, 60.0, (), float32)
    shape: Discrete(7, start=1)
    start_position: Box(100.0, 400.0, (2,), float64)
goal:
    angle: Box(-6.283185307179586, 6.283185307179586, (), float64)
    color: Box(0, 255, (3,), uint8)
    position: Box(50.0, 450.0, (2,), float64)
    scale: Box(20.0, 60.0, (), float32)
rendering:
    render_goal: Discrete(2)
agent:
    angle: Box(-6.283185307179586, 6.283185307179586, (), float64)
    color: Box(0, 255, (3,), uint8)
    scale: Box(20.0, 60.0, (), float32)
    shape: Discrete(8)
    start_position: Box(50.0, 450.0, (2,), float64)
    velocity: Box(0.0, 512.0, (2,), float64)
background:
    color: Box(0, 255, (3,), uint8)
block:
    angle: Box(-6.283185307179586, 6.283185307179586, (), float64)
    color: Box(0, 255, (3,), uint8)
    scale: Box(20.0, 60.0, (), float32)
    shape: Discrete(7, start=1)
    start_position: Box(100.0, 400.0, (2,), float64)
goal:
    angle: Box(-6.283185307179586, 6.283185307179586, (), float64)
    color: Box(0, 255, (3,), uint8)
    position: Box(50.0, 450.0, (2,), float64)
    scale: Box(20.0, 60.0, (), float32)
rendering:
    render_goal: Discrete(2)
# Out:
# 2026-04-06 23:20:04.919 | INFO     | stable_worldmodel.world:__init__:123 - 🌍🌍🌍 World swm/PushT-v1 initialized 🌍🌍🌍
# 2026-04-06 23:20:04.919 | INFO     | stable_worldmodel.world:__init__:125 - 🕹️ 🕹️ 🕹️ Action space 🕹️ 🕹️ 🕹️
# 2026-04-06 23:20:04.920 | INFO     | stable_worldmodel.world:__init__:126 - Box(-1.0, 1.0, (1, 2), float32)
# 2026-04-06 23:20:04.920 | INFO     | stable_worldmodel.world:__init__:128 - 👁️ 👁️ 👁️ Observation space 👁️ 👁️ 👁️
# 2026-04-06 23:20:04.921 | INFO     | stable_worldmodel.world:__init__:129 - Dict('proprio': Box(0.0, 512.0, (1, 4), float64), 'state': Box(0.0, [[512.         512.         512.         512.           6.28318531
#   512.         512.        ]], (1, 7), float64))
# 2026-04-06 23:20:04.921 | INFO     | stable_worldmodel.world:__init__:132 - ⚗️ ⚗️ ⚗️ Variation space ⚗️ ⚗️ ⚗️
# agent:
#     angle: Box(-6.283185307179586, 6.283185307179586, (), float64)
#     color: Box(0, 255, (3,), uint8)
#     scale: Box(20.0, 60.0, (), float32)
#     shape: Discrete(8)
#     start_position: Box(50.0, 450.0, (2,), float64)
#     velocity: Box(0.0, 512.0, (2,), float64)
# background:
#     color: Box(0, 255, (3,), uint8)
# block:
#     angle: Box(-6.283185307179586, 6.283185307179586, (), float64)
#     color: Box(0, 255, (3,), uint8)
#     scale: Box(20.0, 60.0, (), float32)
#     shape: Discrete(7, start=1)
#     start_position: Box(100.0, 400.0, (2,), float64)
# goal:
#     angle: Box(-6.283185307179586, 6.283185307179586, (), float64)
#     color: Box(0, 255, (3,), uint8)
#     position: Box(50.0, 450.0, (2,), float64)
#     scale: Box(20.0, 60.0, (), float32)
# rendering:
#     render_goal: Discrete(2)
# world created: <stable_worldmodel.world.World object at 0x16d9157e0>

# %%
print(dir(world))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_dump_step_data', '_handle_done_ep', '_history_size', '_init_h5_datasets', '_reset_single_env', '_write_episode', 'action_space', 'close', 'envs', 'evaluate', 'evaluate_from_dataset', 'infos', 'num_envs', 'observation_space', 'policy', 'record_dataset', 'record_video', 'reset', 'rewards', 'seed', 'set_policy', 'single_action_space', 'single_observation_space', 'single_variation_space', 'states', 'step', 'terminateds', 'truncateds', 'variation_space']

# %%
obs = world.reset()
print(type(obs))
print(obs)
# Out:
# <class 'NoneType'>
# None
# /opt/anaconda3/envs/wm/lib/python3.10/site-packages/gymnasium/spaces/box.py:424: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
